# %%
# this is a rudimentary calculator written in python

print("1. Addition\n 2. Subtraction\n 3. Multiplication\n 4. Division\n 5. Exponents\n 6. Roots")

operation = input("Type the number of the corresponding operation you'd like to use:\n")

if(operation == '1'): #addition
    
    answer = 0;

    amount_add = int(input("How many numbers would you like to add? "))
    
    if(amount_add < 2): #error message for less than 2 numbers being added
        print("Invalid Entry. Must add at least 2 numbers.")
    else:
        for x in range(1, amount_add + 1): #interates for amount of numbers added
            to_add = float(input("Enter number " + str(x) + ": "))
            answer = answer + to_add
        
        print("Answer: " + str(answer))
    
elif(operation == '2'): #subtraction

    print("Please input the numbers you would like to substract. (first - second) ")
    
    sub_first = float(input("first number: "))
    sub_second = float(input("second number: "))
    
    print("Answer: " + str(sub_first - sub_second))
    
elif(operation == '3'): #multiplication
    
    amount_mult = int(input("How many numbers would you like to multiply? "))
    
    if(amount_mult < 2): #error message for less than 2 numbers being added
        print("Invalid Entry. Must multiply at least 2 numbers.")
    else:
        to_mult_first = float(input("Enter number 1: ")) #keeps track of the first number to be multiplied
    
        for x in range(2, amount_mult + 1): #interates for amount of numbers multiplied
            to_mult = float(input("Enter number " + str(x) + ": "))
            to_mult_first = to_mult_first * to_mult #multiplies the new number to its previous product
        
        print("Answer: " + str(to_mult_first))
        
elif(operation == '4'): #division
    
    print("Please input the numbers you would like to divide. (first/second) ")
    
    div_first = float(input("first number: "))
    div_second = float(input("second number: "))
    
    print("Answer: " + str(div_first / div_second)) 

elif(operation == '5'): #exponents
    
    print("Please input the numbers you would like to use. (base^exponent)\n")
    print("Note: the exponent must be an integer.")
    
    base = float(input("base: "))
    exponent = int(input("exponent: "))
    
    if(exponent == 0): #roots
        
        print("Answer: 1")
    else:
    
        answer = base**exponent #raising the base to its exponent

        print("Answer: " + str(answer))
        
elif(operation == '6'): #roots

    print("Please input the numbers you would like to use. (n√base)")
    print("Note: the root must be an integer.")
    
    n = float(input("n: "))
    base = float(input("base: "))
    
    answer = base ** (1/root) #calculates the "n" root of the base
    print(str(answer))
    
else: #checks for invalid operation entry
    print("Invalid Entry.")
